# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
SoE = pd.read_csv('2022_2학기 경제학부.csv')
SoBA = pd.read_csv('2022_2학기 경영학부.csv')
DoAS = pd.read_csv('2022_2학기 보험계리학과.csv')

# %%
# Out:
#     Unnamed: 0                Unnamed: 1    Unnamed: 2   Unnamed: 3  \
# 0          NaN  2022-2 보험계리학과 학생회비 통장 내역           NaN          NaN
# 1          NaN                       NaN           NaN          NaN
# 2          NaN                        날짜            내용           수입
# 3          NaN                       NaN           NaN          NaN
# 4          NaN                2022-08-27      이마트  트레이          NaN
# ..         ...                       ...           ...          ...
# 56         NaN                2022-12-13       와플대학 안산          NaN
# 57         NaN                2022-12-13       블루포트 한양   ₩ 111,900
# 58         NaN                2022-12-13       블루포트 한양          NaN
# 59         NaN                2022-12-14           김민희     ₩ 4,990
# 60         NaN                2022/12/17  9.17 ~ 12.16       ₩ 843
#
#      Unnamed: 4     Unnamed: 5 Unnamed: 6  \
# 0           NaN            NaN        NaN
# 1           NaN            NaN  예금주 : 김민희
# 2            지출             잔액         사업
# 3           NaN   ₩ 4,845,373         NaN
# 4     ₩ 91,760    ₩ 4,753,613          꿈터
# ..          ...            ...        ...
# 56   ₩ 301,000    ₩ 2,928,653   기말고사 야식사업
# 57          NaN   ₩ 3,040,553   기말고사 야식사업
# 58    ₩ 65,700    ₩ 2,974,853   기말고사 야식사업
# 59          NaN   ₩ 2,979,843         NaN
# 60          NaN   ₩ 2,980,686         NaN
#
#                                            Unnamed: 7 Unnamed: 8
# 0                                                 NaN        NaN
# 1                          계좌번호 : 신한은행 110-535-560290        NaN
# 2                                                세부항목        영수증
# 3                                                 NaN        NaN
# 4   복순도가 손막걸리 10,980*1 + 피지트리 700ml 20,980*1 + 엑스 ...          O
# ..                                                ...        ...
# 56  애플시나몬와플 2900*17 + 오레오누텔라 3700 * 36 + 아메리카노 250...          O
# 57                                      결제취소, 기타란에 설명          O
# 58                아메리카노 2100 * 3 + 아이스티 2200 * 27 결제           O
# 59                                   출금오류 수정, 기타란에 설명          △
# 60                                                 이자          △
#
# [61 rows x 9 columns]

# %%
SoE.columns = ['Untitled 0', '날짜', '내용', '수입', '지출', '잔액', '사업', '세부항목', '영수증', 'Untitled 1']
SoE1 = SoE.drop([0, 1, 2])
S_E = SoE1.drop(['Untitled 0', 'Untitled 1'], axis = 1)
S_E
# Out:
#             날짜           내용              수입           지출           잔액  \
# 3          NaN      학생회비 이월   ₩ 10,119,613           NaN  ₩10,119,613
# 4   2022-06-18  03.19~06.17        ₩ 2,480           NaN  ₩10,122,093
# 5   2022-06-30       이단비 토익             NaN    ₩ 24,000   ₩10,098,093
# 6   2022-06-30      김도은 한능검             NaN    ₩ 11,000   ₩10,087,093
# 7   2022-06-30      이동헌 한능검             NaN    ₩ 11,000   ₩10,076,093
# ..         ...          ...             ...          ...          ...
# 83  2022-12-14     맘스터치 (고잔             NaN   ₩ 528,000    ₩3,163,978
# 84  2022-12-16           쿠팡             NaN    ₩ 55,700    ₩3,108,278
# 85  2022-12-17  09.17~12.16        ₩ 1,342           NaN   ₩3,109,620
# 86  2022-12-24      (주)우아한형             NaN    ₩ 50,000    ₩3,059,620
# 87  2022-12-31       박영민 컴활             NaN    ₩ 20,750    ₩3,038,870
#
#                사업                                               세부항목  영수증
# 3             NaN                                                NaN  NaN
# 4            예금이자                                               예금이자    △
# 5    자격증 응시료 지원사업                                    토익 응시료 지원 24000    △
# 6    자격증 응시료 지원사업                            한국사 능력검정시험 응시료 지원 11000    △
# 7    자격증 응시료 지원사업                            한국사 능력검정시험 응시료 지원 11000    △
# ..            ...                                                ...  ...
# 83  2학기 기말고사 야식사업                               맘스터치 싸이버거 세트 6600*80    ○
# 84     학생회실 비품 구비  코멧 투명 박스테이프 10개 14990\n피스코리아 편한 호치키스 50+리필33호침...    ○
# 85           예금이자                                               예금이자    △
# 86       12월 연말사업                                      배민상품권 10000*5    ○
# 87   자격증 응시료 지원사업                               컴퓨터활용능력 응시료 지원 20750    △
#
# [85 rows x 8 columns]

# %%
SoBA.columns = ['Untitled 0', '날짜', '내용', '수입', '지출', '잔액', '사업', '세부항목', '영수증']
SoBA1 = SoBA.drop([0, 1, 2])
S_BA = SoBA1.drop('Untitled 0', axis = 1)
S_BA
# Out:
#             날짜           내용              수입           지출              잔액  \
# 3          NaN   전월 학생회 이월금   ₩ 16,305,506           NaN   ₩ 16,305,506
# 4   2022-07-18      쿠팡와우월회비             NaN     ₩ 4,990    ₩ 16,300,516
# 5   2022-07-20          박유진             NaN    ₩ 10,000    ₩ 16,290,516
# 6   2022-07-20          홍수진             NaN     ₩ 5,000    ₩ 16,285,516
# 7   2022-07-20          옥민희             NaN     ₩ 5,000    ₩ 16,280,516
# 8   2022-07-20          유승연             NaN     ₩ 5,000    ₩ 16,275,516
# 9   2022-07-20          윤채은        ₩ 4,990           NaN   ₩ 16,280,506
# 10  2022-07-20          유승연             NaN    ₩ 10,000    ₩ 16,270,506
# 11  2022-07-22          박유진        ₩ 5,000           NaN   ₩ 16,275,506
# 12  2022-07-25          이윤빈             NaN   ₩ 100,000    ₩ 16,175,506
# 13  2022-08-21           쿠팡             NaN    ₩ 29,700    ₩ 16,145,806
# 14  2022-08-24     (PG)이니시스             NaN    ₩ 18,900    ₩ 16,126,906
# 15  2022-08-25           쿠팡       ₩ 29,700           NaN   ₩ 16,156,606
# 16  2022-08-26     (PG)이니시스       ₩ 18,900           NaN   ₩ 16,175,506
# 17  2022-08-26          박인호             NaN   ₩ 288,000    ₩ 15,887,506
# 18  2022-08-26          김영규             NaN    ₩ 20,000    ₩ 15,867,506
# 19  2022-08-26      케이-슈퍼마켓             NaN    ₩ 41,900    ₩ 15,825,606
# 20  2022-08-26      케이-슈퍼마켓             NaN     ₩ 3,300    ₩ 15,822,306
# 21  2022-09-15          윤채은             NaN   ₩ 129,000    ₩ 15,693,306
# 58  2022-12-18      쿠팡와우월회비             NaN     ₩ 4,990     ₩ 8,789,838
# 59  2022-12-20          윤채은        ₩ 4,990           NaN    ₩ 8,794,828
#
#                 사업                                               세부항목  영수증
# 3      전월 학생회비 이월금                                        전월 학생회비 이월금  NaN
# 4           연결계좌오류  카드연결계좌 착각 (인터넷 거래 중 개인 계좌와 헷갈려서 결제함, 결산안 시트 11...    △
# 5         응시료지원 사업  박유진 응시료지원 사업 (오픽), (착오 송금으로 5,000원 더 송금, 추후 환불...    △
# 6         응시료지원 사업                                 홍수진 응시료 지원 사업 (토익)    △
# 7         응시료지원 사업                                  옥민희 응시료지원 사업 (토익)    △
# 8         응시료지원 사업  유승연 응시료지원 사업 (컴활 실기 3번), (착오 송금으로 10,000원 덜 보냄...    △
# 9           연결계좌오류                                카드연결계좌 착각에 따른 금액 지급    △
# 10        응시료지원 사업                 유승연 응시료지원 사업 (착오 송금으로 인한 추가 금액 송금)    △
# 11        응시료지원 사업                    박유진 응시료지원 사업 (착오 송금으로 인한 반환 환불)    △
# 12            학생회비                                        이윤빈 학생회비 환불    △
# 13          꿈꾸는배움터  꿈꾸는 배움터 명찰 구입 (경상대 학생회에서 일괄 구입한다고 해서 환불, 결산안 시...    △
# 14          꿈꾸는배움터  꿈꾸는 배움터 경영학부 현수막 제작 (꿈꾸는 배움터 전 배송 불가하여 환불, 결산안...    △
# 15          꿈꾸는배움터                                      꿈꾸는 배움터 명찰 환불    △
# 16          꿈꾸는배움터                                꿈꾸는 배움터 경영학부 현수막 환불    △
# 17          꿈꾸는배움터                                         문과대 MT 지원금    △
# 18          꿈꾸는배움터          꿈꾸는 배움터 경영학부 현수막 제작 (현수막 20,000*1=20,000)    ○
# 19          꿈꾸는배움터  꿈꾸는 배움터 경영학부 레크레이션 필요 물품 구입 (케이-슈퍼마켓 CJ_이탈리따스파...    ○
# 20          꿈꾸는배움터  꿈꾸는 배움터 경영학부 레크레이션 필요 물품 추가 구입 (케이-슈퍼마켓 줄자3m(6...    ○
# 21      추석 N행시 이벤트  추석 N행시 이벤트 상품 결제액 재무국 윤채은에게 송금 (스테이크 3종 세트: 25...    △
# 22        경상대 체육대전  경상대 체육대전 경영학부 현수막, 포스터 제작 (현수막 25,000*2=50,000...    ○
# 23        경상대 체육대전  경상대 체육대전 간식 구입 (핫도그 2,800*50=140,000, 콜라 1200*...    ○
# 24           이자 수익                                  06.18~09.16 이자 수익    △
# 25         물품 대여사업  물품 대여사업 필요 물품 구입 (엔보우 2채널 블루투스 무소음 무선마우스 화이트 9...    △
# 26         물품 대여사업  물품 대여사업 필요 물품 추가 구입 (PANTONE 파워뱅크 보조배터리 22,500...    △
# 27         물품 대여사업                                    물품 대여사업 대자보 인쇄     ○
# 28  경영 E-SPORTS 대회             경영 E-SPORTS '폴가이즈' 대회  우승 상금 우동윤에게 송금     △
# 55       창작의 고통 사업  창작의 고통 사업 상품 결제액 재무국 김서영에게 송금 (조말론런던 핸드크림 50ML...    △
# 56       창작의 고통 사업  창작의 고통 사업 상품 결제액 재무국 여수연에게 송금 (스타벅스 아이스 카페 아메리...    △
# 57           이자 수익                                  09.17~12.16 이자 수익    △
# 58          연결계좌오류  카드연결계좌 착각 (인터넷 거래 중 개인 계좌와 헷갈려서 결제함, 결산안 시트 61...    △
# 59          연결계좌오류                                카드연결계좌 착각에 따른 금액 지급    △

# %%
DoAS.columns = ['Untitled 0', '날짜', '내용', '수입', '지출', '잔액', '사업', '세부항목', '영수증']
DoAS1 = DoAS.drop([0, 1, 2])
D_AS = DoAS1.drop('Untitled 0', axis = 1)
D_AS
# Out:
#             날짜            내용           수입           지출             잔액  \
# 3          NaN           NaN          NaN          NaN   ₩ 4,845,373
# 4   2022-08-27      이마트  트레이          NaN    ₩ 91,760    ₩ 4,753,613
# 5   2022-08-29        이미지114          NaN    ₩ 11,000    ₩ 4,742,613
# 6   2022-09-02           진다원          NaN     ₩ 2,700    ₩ 4,739,913
# 7   2022-09-02           현석우          NaN    ₩ 28,500    ₩ 4,711,413
# 8   2022-09-16       봉구스밥버거(          NaN   ₩ 155,000    ₩ 4,556,413
# 9   2022-09-17   06.18~09.16     ₩ 1,030           NaN   ₩ 4,557,443
# 10  2022-09-28       쿠팡(쿠페이)          NaN     ₩ 4,990    ₩ 4,552,453
# 11  2022-10-14       피자스쿨안산한          NaN   ₩ 133,700    ₩ 4,418,753
# 12  2022-10-14           더치킨          NaN   ₩ 205,700    ₩ 4,213,053
# 13  2022-10-14       케이-슈퍼마켓          NaN    ₩ 26,000    ₩ 4,187,053
# 14  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,182,053
# 15  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,177,053
# 16  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,172,053
# 17  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,167,053
# 18  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,162,053
# 19  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,157,053
# 20  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,152,053
# 21  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,147,053
# 22  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,142,053
# 23  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,137,053
# 24  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,132,053
# 25  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,127,053
# 26  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,122,053
# 27  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,117,053
# 28  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,112,053
# 29  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,107,053
# 30  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,102,053
# 31  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,097,053
# 32  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,092,053
# 33  2022-10-31         아레나PC          NaN     ₩ 5,000    ₩ 4,087,053
# 34  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,084,053
# 35  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,081,053
# 36  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,078,053
# 37  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,075,053
# 38  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,072,053
# 39  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,069,053
# 40  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,066,053
# 41  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,063,053
# 42  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,060,053
# 43  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,057,053
# 44  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,054,053
# 45  2022-10-31         아레나PC          NaN     ₩ 3,000    ₩ 4,051,053
# 46  2022-10-31           유형동          NaN   ₩ 200,000    ₩ 3,851,053
# 47  2022-10-31           김민균          NaN    ₩ 50,000    ₩ 3,801,053
# 48  2022-10-31           김태영          NaN    ₩ 30,000    ₩ 3,771,053
# 49  2022-10-31           김승재          NaN    ₩ 10,000    ₩ 3,761,053
# 50  2022-10-31           양창민          NaN    ₩ 20,000    ₩ 3,741,053
# 51  2022-10-31           이승후          NaN    ₩ 20,000    ₩ 3,721,053
# 52  2022-10-31           정민교          NaN    ₩ 20,000    ₩ 3,701,053
# 53  2022-11-24      김은화(돈푸락)          NaN   ₩ 308,000    ₩ 3,393,053
# 54  2022-12-07       네이버파이낸셜          NaN    ₩ 51,500    ₩ 3,341,553
# 55  2022-12-13       블루포트 한양          NaN   ₩ 111,900    ₩ 3,229,653
# 56  2022-12-13       와플대학 안산          NaN   ₩ 301,000    ₩ 2,928,653
# 57  2022-12-13       블루포트 한양   ₩ 111,900           NaN   ₩ 3,040,553
# 58  2022-12-13       블루포트 한양          NaN    ₩ 65,700    ₩ 2,974,853
# 59  2022-12-14           김민희     ₩ 4,990           NaN   ₩ 2,979,843
# 60  2022/12/17  9.17 ~ 12.16       ₩ 843           NaN   ₩ 2,980,686
#
#                 사업                                               세부항목  영수증
# 3              NaN                                                NaN  NaN
# 4               꿈터  복순도가 손막걸리 10,980*1 + 피지트리 700ml 20,980*1 + 엑스 ...    O
# 5               꿈터                                            플랜카드 인쇄    O
# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17476\650192056.py in <module>
# ----> 1 D_AS['지출'].sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11072             **kwargs,
#   11073         ):
# > 11074             return NDFrame.sum(
#   11075                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   11076             )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10792         **kwargs,
#   10793     ):
# > 10794         return self._min_count_stat_function(
#   10795             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10796         )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10774             )
#   10775
# > 10776         return self._reduce(
#   10777             func,
#   10778             name=name,
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4469                 )
#    4470             with np.errstate(all="ignore"):
# -> 4471                 return op(delegate, skipna=skipna, **kwds)
#    4472
#    4473     def _reindex_indexer(
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     408             mask = isna(values)
#     409
# --> 410         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     411
#     412         if datetimelike:
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in newfunc(values, axis, **kwargs)
#     481             return np.array(results)
#     482
# --> 483         return func(values, axis=axis, **kwargs)
#     484
#     485     return cast(F, newfunc)
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in nansum(values, axis, skipna, min_count, mask)
#     621         dtype_sum = np.dtype(np.float64)
#     622
# --> 623     the_sum = values.sum(axis, dtype=dtype_sum)
#     624     the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     625
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#4
x = np.arange(3)


department = ['S_E', 'S_BA', 'D_AS']
values = [10119613, 16305506, 4845373]

plt.bar(x, values)
plt.xticks(x, department)
plt.show()

# %%
#3
x = np.arange(3)



department = ['S_E', 'S_BA', 'D_AS']
values = [10119613, 16305506, 4845373]

plt.bar(x, values)
plt.xticks(x, department)
plt.show()

# %%
S_E['지출'].type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17476\817503912.py in <module>
# ----> 1 S_E['지출'].type
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'type'
